# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/passwords.csv")

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df["label"] = df["label"].str.lower()

# %%
df["label"].unique()
# Out:
# <StringArray>
# ['weak', 'medium', 'strong']
# Length: 3, dtype: str

# %%
df.to_csv("../data/passwords_clean.csv", index=False)
